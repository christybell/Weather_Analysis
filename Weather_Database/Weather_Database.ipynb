# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | charlottesville
# Processing Record 3 of Set 1 | port lincoln
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | kabo
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | port elizabeth
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 1 | asosa
# Processing Record 13 of Set 1 | yugorsk
# Processing Record 14 of Set 1 | constitucion
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | llanes
# Processing Record 20 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 1 | honningsvag
# Processing Record 22 of Set 1 | bonnyville
# Processing Record 23 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 1 | prainha
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | mahajanga
# Processing Record 28 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | progreso
# Processing Record 31 of Set 1 | sechura
# Processing Record 32 of Set 1 | tiksi
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | nieuw amsterdam
# Processing Record 35 of Set 1 | monrovia
# Processing Record 36 of Set 1 | lata
# Processing Record 37 of Set 1 | asyut
# Processing Record 38 of Set 1 | talnakh
# Processing Record 39 of Set 1 | doha
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | general delgado
# Processing Record 43 of Set 1 | fortuna
# Processing Record 44 of Set 1 | ostrovnoy
# Processing Record 45 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 1 | pozoblanco
# Processing Record 47 of Set 1 | ponta do sol
# Processing Record 48 of Set 1 | mahebourg
# Processing Record 49 of Set 1 | lima
# Processing Record 50 of Set 1 | zyryanka
# Processing Record 1 of Set 2 | malie
# Processing Record 2 of Set 2 | kaeo
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | cape town
# Processing Record 5 of Set 2 | jining
# Processing Record 6 of Set 2 | port alfred
# Processing Record 7 of Set 2 | marica
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | surgut
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | sadri
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | saint-philippe
# Processing Record 14 of Set 2 | lingyuan
# Processing Record 15 of Set 2 | vaitape
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | dickinson
# Processing Record 18 of Set 2 | gamba
# Processing Record 19 of Set 2 | messias
# Processing Record 20 of Set 2 | bathsheba
# Processing Record 21 of Set 2 | kasongo-lunda
# Processing Record 22 of Set 2 | upernavik
# Processing Record 23 of Set 2 | lompoc
# Processing Record 24 of Set 2 | alta floresta
# Processing Record 25 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 26 of Set 2 | viransehir
# Processing Record 27 of Set 2 | aklavik
# Processing Record 28 of Set 2 | carnarvon
# Processing Record 29 of Set 2 | flinders
# Processing Record 30 of Set 2 | east london
# Processing Record 31 of Set 2 | byumba
# Processing Record 32 of Set 2 | isfana
# Processing Record 33 of Set 2 | tuatapere
# Processing Record 34 of Set 2 | hilo
# Processing Record 35 of Set 2 | touros
# Processing Record 36 of Set 2 | isangel
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | tessalit
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | bhuban
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | ladushkin
# Processing Record 45 of Set 2 | myaundzha
# Processing Record 46 of Set 2 | nyrob
# Processing Record 47 of Set 2 | fuxin
# Processing Record 48 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 2 | gander
# Processing Record 50 of Set 2 | ako
# Processing Record 1 of Set 3 | barbosa ferraz
# Processing Record 2 of Set 3 | takoradi
# Processing Record 3 of Set 3 | botwood
# Processing Record 4 of Set 3 | victoria
# Processing Record 5 of Set 3 | dikson
# Processing Record 6 of Set 3 | birjand
# Processing Record 7 of Set 3 | yarada
# Processing Record 8 of Set 3 | moate
# Processing Record 9 of Set 3 | ambilobe
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | sibenik
# Processing Record 12 of Set 3 | bay roberts
# Processing Record 13 of Set 3 | rosario
# Processing Record 14 of Set 3 | yulara
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | paita
# Processing Record 17 of Set 3 | chhatapur
# Processing Record 18 of Set 3 | aranda de duero
# Processing Record 19 of Set 3 | galdar
# Processing Record 20 of Set 3 | maralal
# Processing Record 21 of Set 3 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 22 of Set 3 | daman
# Processing Record 23 of Set 3 | ngawen
# Processing Record 24 of Set 3 | henties bay
# Processing Record 25 of Set 3 | ukiah
# Processing Record 26 of Set 3 | busselton
# Processing Record 27 of Set 3 | fairmont
# Processing Record 28 of Set 3 | puerto ayora
# Processing Record 29 of Set 3 | jamestown
# Processing Record 30 of Set 3 | goderich
# Processing Record 31 of Set 3 | urengoy
# Processing Record 32 of Set 3 | bahia blanca
# Processing Record 33 of Set 3 | verkhoyansk
# Processing Record 34 of Set 3 | chicama
# Processing Record 35 of Set 3 | camacupa
# Processing Record 36 of Set 3 | tarime
# Processing Record 37 of Set 3 | san juan
# Processing Record 38 of Set 3 | khatanga
# Processing Record 39 of Set 3 | zouxian
# City not found. Skipping...
# Processing Record 40 of Set 3 | zima
# Processing Record 41 of Set 3 | nchelenge
# Processing Record 42 of Set 3 | zhicheng
# Processing Record 43 of Set 3 | surt
# Processing Record 44 of Set 3 | hobart
# Processing Record 45 of Set 3 | onverwacht
# Processing Record 46 of Set 3 | qaanaaq
# Processing Record 47 of Set 3 | campbell river
# Processing Record 48 of Set 3 | tiznit
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | laguna
# Processing Record 2 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 3 of Set 4 | ventspils
# Processing Record 4 of Set 4 | vreed en hoop
# City not found. Skipping...
# Processing Record 5 of Set 4 | maceio
# Processing Record 6 of Set 4 | saskylakh
# Processing Record 7 of Set 4 | kruisfontein
# Processing Record 8 of Set 4 | bijie
# Processing Record 9 of Set 4 | esperance
# Processing Record 10 of Set 4 | wingham
# Processing Record 11 of Set 4 | husavik
# Processing Record 12 of Set 4 | alzamay
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | elizabeth city
# Processing Record 16 of Set 4 | norman wells
# Processing Record 17 of Set 4 | tuktoyaktuk
# Processing Record 18 of Set 4 | abu zabad
# Processing Record 19 of Set 4 | vaini
# Processing Record 20 of Set 4 | geraldton
# Processing Record 21 of Set 4 | tsimlyansk
# Processing Record 22 of Set 4 | moron
# Processing Record 23 of Set 4 | bobrovka
# Processing Record 24 of Set 4 | yar-sale
# Processing Record 25 of Set 4 | anadyr
# Processing Record 26 of Set 4 | cayenne
# Processing Record 27 of Set 4 | bonfim
# Processing Record 28 of Set 4 | fuling
# Processing Record 29 of Set 4 | canon city
# Processing Record 30 of Set 4 | bambous virieux
# Processing Record 31 of Set 4 | makrikapa
# City not found. Skipping...
# Processing Record 32 of Set 4 | shimoda
# Processing Record 33 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 4 | urulga
# City not found. Skipping...
# Processing Record 35 of Set 4 | andijon
# Processing Record 36 of Set 4 | padang
# Processing Record 37 of Set 4 | tasiilaq
# Processing Record 38 of Set 4 | mukhen
# Processing Record 39 of Set 4 | basco
# Processing Record 40 of Set 4 | prince rupert
# Processing Record 41 of Set 4 | hualmay
# Processing Record 42 of Set 4 | ponta delgada
# Processing Record 43 of Set 4 | lebu
# Processing Record 44 of Set 4 | kifri
# Processing Record 45 of Set 4 | north bend
# Processing Record 46 of Set 4 | noumea
# Processing Record 47 of Set 4 | atagay
# Processing Record 48 of Set 4 | hofn
# Processing Record 49 of Set 4 | krasnoselkup
# Processing Record 50 of Set 4 | muroto
# Processing Record 1 of Set 5 | pevek
# Processing Record 2 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 5 | san quintin
# Processing Record 4 of Set 5 | alofi
# Processing Record 5 of Set 5 | upata
# Processing Record 6 of Set 5 | fort nelson
# Processing Record 7 of Set 5 | jujuy
# City not found. Skipping...
# Processing Record 8 of Set 5 | madras
# Processing Record 9 of Set 5 | thanh hoa
# Processing Record 10 of Set 5 | chokurdakh
# Processing Record 11 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 5 | hefei
# Processing Record 13 of Set 5 | townsville
# Processing Record 14 of Set 5 | mwinilunga
# Processing Record 15 of Set 5 | bosansko grahovo
# Processing Record 16 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 17 of Set 5 | sistranda
# Processing Record 18 of Set 5 | rocha
# Processing Record 19 of Set 5 | te anau
# Processing Record 20 of Set 5 | kapit
# Processing Record 21 of Set 5 | tabuk
# Processing Record 22 of Set 5 | katsuura
# Processing Record 23 of Set 5 | bilibino
# Processing Record 24 of Set 5 | souillac
# Processing Record 25 of Set 5 | litoral del san juan
# City not found. Skipping...
# Processing Record 26 of Set 5 | maniwaki
# Processing Record 27 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 5 | coquimbo
# Processing Record 29 of Set 5 | vagur
# Processing Record 30 of Set 5 | teya
# Processing Record 31 of Set 5 | brazzaville
# Processing Record 32 of Set 5 | mount gambier
# Processing Record 33 of Set 5 | sisimiut
# Processing Record 34 of Set 5 | agadez
# Processing Record 35 of Set 5 | vila franca do campo
# Processing Record 36 of Set 5 | bundaberg
# Processing Record 37 of Set 5 | belyy yar
# Processing Record 38 of Set 5 | marinette
# Processing Record 39 of Set 5 | nantucket
# Processing Record 40 of Set 5 | sheffield
# Processing Record 41 of Set 5 | port-cartier
# Processing Record 42 of Set 5 | ancud
# Processing Record 43 of Set 5 | emporia
# Processing Record 44 of Set 5 | chubbuck
# Processing Record 45 of Set 5 | upington
# Processing Record 46 of Set 5 | zalantun
# Processing Record 47 of Set 5 | makakilo city
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | luderitz
# Processing Record 50 of Set 5 | ketchikan
# Processing Record 1 of Set 6 | samarai
# Processing Record 2 of Set 6 | severo-kurilsk
# Processing Record 3 of Set 6 | bredasdorp
# Processing Record 4 of Set 6 | bhadrachalam
# Processing Record 5 of Set 6 | safaga
# Processing Record 6 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 6 | esmeralda
# Processing Record 8 of Set 6 | kupang
# Processing Record 9 of Set 6 | fort-shevchenko
# Processing Record 10 of Set 6 | hamilton
# Processing Record 11 of Set 6 | kimbe
# Processing Record 12 of Set 6 | canals
# Processing Record 13 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 6 | nizhniy baskunchak
# Processing Record 15 of Set 6 | altay
# Processing Record 16 of Set 6 | timra
# Processing Record 17 of Set 6 | vigrestad
# Processing Record 18 of Set 6 | sao filipe
# Processing Record 19 of Set 6 | boundiali
# Processing Record 20 of Set 6 | rundu
# Processing Record 21 of Set 6 | warrnambool
# Processing Record 22 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 6 | chulman
# Processing Record 24 of Set 6 | hami
# Processing Record 25 of Set 6 | havoysund
# Processing Record 26 of Set 6 | roma
# Processing Record 27 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 28 of Set 6 | sitka
# Processing Record 29 of Set 6 | mahibadhoo
# Processing Record 30 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 6 | saint george
# Processing Record 32 of Set 6 | sao jose da coroa grande
# Processing Record 33 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 6 | mariental
# Processing Record 36 of Set 6 | saint-augustin
# Processing Record 37 of Set 6 | wattegama
# Processing Record 38 of Set 6 | glace bay
# Processing Record 39 of Set 6 | bengkulu
# Processing Record 40 of Set 6 | thompson
# Processing Record 41 of Set 6 | bako
# Processing Record 42 of Set 6 | atherton
# Processing Record 43 of Set 6 | hudson bay
# Processing Record 44 of Set 6 | plattsburgh
# Processing Record 45 of Set 6 | deputatskiy
# Processing Record 46 of Set 6 | dipkarpaz
# City not found. Skipping...
# Processing Record 47 of Set 6 | russell
# Processing Record 48 of Set 6 | vikhorevka
# Processing Record 49 of Set 6 | koumac
# Processing Record 50 of Set 6 | hobyo
# Processing Record 1 of Set 7 | enderby
# Processing Record 2 of Set 7 | nome
# Processing Record 3 of Set 7 | fomboni
# Processing Record 4 of Set 7 | naryan-mar
# Processing Record 5 of Set 7 | vestmannaeyjar
# Processing Record 6 of Set 7 | alexandria
# Processing Record 7 of Set 7 | paraiso
# Processing Record 8 of Set 7 | codrington
# Processing Record 9 of Set 7 | ust-maya
# Processing Record 10 of Set 7 | bethel
# Processing Record 11 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 12 of Set 7 | torbay
# Processing Record 13 of Set 7 | sayyan
# Processing Record 14 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 7 | ungaran
# Processing Record 16 of Set 7 | seoul
# Processing Record 17 of Set 7 | mtimbira
# Processing Record 18 of Set 7 | baghdad
# Processing Record 19 of Set 7 | burkhala
# City not found. Skipping...
# Processing Record 20 of Set 7 | sambava
# Processing Record 21 of Set 7 | paka
# Processing Record 22 of Set 7 | koson
# Processing Record 23 of Set 7 | launceston
# Processing Record 24 of Set 7 | helena
# Processing Record 25 of Set 7 | dzilam gonzalez
# Processing Record 26 of Set 7 | bowral
# Processing Record 27 of Set 7 | jiazi
# Processing Record 28 of Set 7 | saryg-sep
# Processing Record 29 of Set 7 | razole
# Processing Record 30 of Set 7 | castro
# Processing Record 31 of Set 7 | voznesenye
# Processing Record 32 of Set 7 | qaqortoq
# Processing Record 33 of Set 7 | erenhot
# Processing Record 34 of Set 7 | severo-yeniseyskiy
# Processing Record 35 of Set 7 | lebyazhye
# Processing Record 36 of Set 7 | taoudenni
# Processing Record 37 of Set 7 | guerrero negro
# Processing Record 38 of Set 7 | iralaya
# Processing Record 39 of Set 7 | ust-karsk
# Processing Record 40 of Set 7 | klaksvik
# Processing Record 41 of Set 7 | caborca
# Processing Record 42 of Set 7 | adrar
# Processing Record 43 of Set 7 | sikonge
# Processing Record 44 of Set 7 | skibbereen
# Processing Record 45 of Set 7 | gayny
# Processing Record 46 of Set 7 | vostok
# Processing Record 47 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 7 | vao
# Processing Record 49 of Set 7 | jinhua
# Processing Record 50 of Set 7 | cherskiy
# Processing Record 1 of Set 8 | tura
# Processing Record 2 of Set 8 | ayan
# Processing Record 3 of Set 8 | canillo
# Processing Record 4 of Set 8 | khovu-aksy
# Processing Record 5 of Set 8 | eirunepe
# Processing Record 6 of Set 8 | posse
# Processing Record 7 of Set 8 | poum
# Processing Record 8 of Set 8 | kyshtovka
# Processing Record 9 of Set 8 | comodoro rivadavia
# Processing Record 10 of Set 8 | urucara
# Processing Record 11 of Set 8 | cam ranh
# Processing Record 12 of Set 8 | port augusta
# Processing Record 13 of Set 8 | ballina
# Processing Record 14 of Set 8 | barra bonita
# Processing Record 15 of Set 8 | balabac
# Processing Record 16 of Set 8 | salalah
# Processing Record 17 of Set 8 | vilyuysk
# Processing Record 18 of Set 8 | winnemucca
# Processing Record 19 of Set 8 | cascais
# Processing Record 20 of Set 8 | airai
# Processing Record 21 of Set 8 | auki
# Processing Record 22 of Set 8 | atikokan
# Processing Record 23 of Set 8 | dhidhdhoo
# Processing Record 24 of Set 8 | jardim
# Processing Record 25 of Set 8 | carlsbad
# Processing Record 26 of Set 8 | asfi
# Processing Record 27 of Set 8 | angoche
# Processing Record 28 of Set 8 | aljezur
# Processing Record 29 of Set 8 | port hawkesbury
# Processing Record 30 of Set 8 | buraydah
# Processing Record 31 of Set 8 | orlik
# Processing Record 32 of Set 8 | lapua
# Processing Record 33 of Set 8 | acin
# City not found. Skipping...
# Processing Record 34 of Set 8 | vardo
# Processing Record 35 of Set 8 | avera
# Processing Record 36 of Set 8 | scalloway
# City not found. Skipping...
# Processing Record 37 of Set 8 | changji
# Processing Record 38 of Set 8 | komsomolskiy
# Processing Record 39 of Set 8 | avarua
# Processing Record 40 of Set 8 | dinguiraye
# Processing Record 41 of Set 8 | artyom
# Processing Record 42 of Set 8 | doctor juan manuel frutos
# Processing Record 43 of Set 8 | sivas
# Processing Record 44 of Set 8 | ndele
# Processing Record 45 of Set 8 | vanimo
# Processing Record 46 of Set 8 | necochea
# Processing Record 47 of Set 8 | abalak
# Processing Record 48 of Set 8 | san angelo
# Processing Record 49 of Set 8 | pinheiro machado
# Processing Record 50 of Set 8 | zehdenick
# Processing Record 1 of Set 9 | maxixe
# Processing Record 2 of Set 9 | collie
# Processing Record 3 of Set 9 | tashla
# Processing Record 4 of Set 9 | djibo
# Processing Record 5 of Set 9 | kurilsk
# Processing Record 6 of Set 9 | arman
# Processing Record 7 of Set 9 | college
# Processing Record 8 of Set 9 | kisangani
# Processing Record 9 of Set 9 | port hardy
# Processing Record 10 of Set 9 | havre-saint-pierre
# Processing Record 11 of Set 9 | payyannur
# Processing Record 12 of Set 9 | tevaitoa
# Processing Record 13 of Set 9 | nhulunbuy
# Processing Record 14 of Set 9 | tarabuco
# Processing Record 15 of Set 9 | chernyshevskiy
# Processing Record 16 of Set 9 | mae sai
# Processing Record 17 of Set 9 | hanna
# Processing Record 18 of Set 9 | igarka
# Processing Record 19 of Set 9 | nanortalik
# Processing Record 20 of Set 9 | carutapera
# Processing Record 21 of Set 9 | zunyi
# Processing Record 22 of Set 9 | srikakulam
# Processing Record 23 of Set 9 | charters towers
# Processing Record 24 of Set 9 | tha mai
# Processing Record 25 of Set 9 | hambantota
# Processing Record 26 of Set 9 | raudeberg
# Processing Record 27 of Set 9 | jind
# Processing Record 28 of Set 9 | hasaki
# Processing Record 29 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 30 of Set 9 | la ronge
# Processing Record 31 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 32 of Set 9 | provideniya
# Processing Record 33 of Set 9 | pakxan
# Processing Record 34 of Set 9 | korla
# Processing Record 35 of Set 9 | las vegas
# Processing Record 36 of Set 9 | luganville
# Processing Record 37 of Set 9 | boca do acre
# Processing Record 38 of Set 9 | biak
# Processing Record 39 of Set 9 | lensk
# Processing Record 40 of Set 9 | edendale
# Processing Record 41 of Set 9 | grand gaube
# Processing Record 42 of Set 9 | tagusao
# Processing Record 43 of Set 9 | valea crisului
# Processing Record 44 of Set 9 | umea
# Processing Record 45 of Set 9 | jahazpur
# Processing Record 46 of Set 9 | kaitangata
# Processing Record 47 of Set 9 | thinadhoo
# Processing Record 48 of Set 9 | neftegorsk
# Processing Record 49 of Set 9 | namwala
# Processing Record 50 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 10 | port blair
# Processing Record 2 of Set 10 | cockburn town
# Processing Record 3 of Set 10 | ixtapa
# Processing Record 4 of Set 10 | moose factory
# Processing Record 5 of Set 10 | merauke
# Processing Record 6 of Set 10 | kodiak
# Processing Record 7 of Set 10 | benghazi
# Processing Record 8 of Set 10 | mopipi
# Processing Record 9 of Set 10 | antofagasta
# Processing Record 10 of Set 10 | sorland
# Processing Record 11 of Set 10 | akonolinga
# Processing Record 12 of Set 10 | barinitas
# Processing Record 13 of Set 10 | pangody
# Processing Record 14 of Set 10 | marawi
# Processing Record 15 of Set 10 | grande-riviere
# City not found. Skipping...
# Processing Record 16 of Set 10 | strezhevoy
# Processing Record 17 of Set 10 | gladstone
# Processing Record 18 of Set 10 | batagay-alyta
# Processing Record 19 of Set 10 | lianzhou
# Processing Record 20 of Set 10 | nanakuli
# Processing Record 21 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 10 | atambua
# Processing Record 23 of Set 10 | manggar
# Processing Record 24 of Set 10 | chemal
# Processing Record 25 of Set 10 | hun
# Processing Record 26 of Set 10 | shubarshi
# Processing Record 27 of Set 10 | gorno-altaysk
# Processing Record 28 of Set 10 | boguchany
# Processing Record 29 of Set 10 | sibolga
# Processing Record 30 of Set 10 | borlange
# City not found. Skipping...
# Processing Record 31 of Set 10 | kodinsk
# Processing Record 32 of Set 10 | uk
# City not found. Skipping...
# Processing Record 33 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 10 | at-bashi
# Processing Record 35 of Set 10 | venice
# Processing Record 36 of Set 10 | buala
# Processing Record 37 of Set 10 | businga
# Processing Record 38 of Set 10 | kuminskiy
# Processing Record 39 of Set 10 | zapolyarnyy
# Processing Record 40 of Set 10 | azad shahr
# Processing Record 41 of Set 10 | marfino
# Processing Record 42 of Set 10 | biltine
# Processing Record 43 of Set 10 | dhar
# Processing Record 44 of Set 10 | tlahualilo
# City not found. Skipping...
# Processing Record 45 of Set 10 | pisco
# Processing Record 46 of Set 10 | chara
# Processing Record 47 of Set 10 | katherine
# Processing Record 48 of Set 10 | ola
# Processing Record 49 of Set 10 | la rioja
# Processing Record 50 of Set 10 | hastings
# Processing Record 1 of Set 11 | gurupi
# Processing Record 2 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 11 | sept-iles
# Processing Record 4 of Set 11 | san patricio
# Processing Record 5 of Set 11 | masterton
# Processing Record 6 of Set 11 | san francisco
# Processing Record 7 of Set 11 | fethiye
# Processing Record 8 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 9 of Set 11 | jatai
# Processing Record 10 of Set 11 | xapuri
# Processing Record 11 of Set 11 | maragogi
# Processing Record 12 of Set 11 | bijni
# Processing Record 13 of Set 11 | uvalde
# Processing Record 14 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 11 | san cristobal
# Processing Record 16 of Set 11 | camopi
# Processing Record 17 of Set 11 | tornio
# Processing Record 18 of Set 11 | suarez
# Processing Record 19 of Set 11 | chamba
# Processing Record 20 of Set 11 | maniitsoq
# Processing Record 21 of Set 11 | marystown
# Processing Record 22 of Set 11 | beni
# Processing Record 23 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 11 | egvekinot
# Processing Record 25 of Set 11 | tommot
# Processing Record 26 of Set 11 | sao joao da barra
# Processing Record 27 of Set 11 | bairiki
# Processing Record 28 of Set 11 | olga
# Processing Record 29 of Set 11 | pokosnoye
# Processing Record 30 of Set 11 | araouane
# Processing Record 31 of Set 11 | mbour
# Processing Record 32 of Set 11 | roebourne
# Processing Record 33 of Set 11 | tautira
# Processing Record 34 of Set 11 | nizhniy odes
# Processing Record 35 of Set 11 | lincoln
# Processing Record 36 of Set 11 | kulhudhuffushi
# Processing Record 37 of Set 11 | muros
# Processing Record 38 of Set 11 | zeya
# Processing Record 39 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 40 of Set 11 | niva
# Processing Record 41 of Set 11 | laiagam
# City not found. Skipping...
# Processing Record 42 of Set 11 | huarmey
# Processing Record 43 of Set 11 | lokachi
# Processing Record 44 of Set 11 | abaza
# Processing Record 45 of Set 11 | persan
# Processing Record 46 of Set 11 | okha
# Processing Record 47 of Set 11 | mango
# Processing Record 48 of Set 11 | port macquarie
# Processing Record 49 of Set 11 | nichinan
# Processing Record 50 of Set 11 | kukes
# Processing Record 1 of Set 12 | kachug
# Processing Record 2 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 3 of Set 12 | pindobacu
# Processing Record 4 of Set 12 | mackay
# Processing Record 5 of Set 12 | mandalgovi
# Processing Record 6 of Set 12 | dubovskoye
# Processing Record 7 of Set 12 | saint-lo
# Processing Record 8 of Set 12 | butterworth
# Processing Record 9 of Set 12 | leningradskiy
# Processing Record 10 of Set 12 | baykit
# Processing Record 11 of Set 12 | kijang
# Processing Record 12 of Set 12 | margate
# Processing Record 13 of Set 12 | along
# Processing Record 14 of Set 12 | ossora
# Processing Record 15 of Set 12 | paldiski
# Processing Record 16 of Set 12 | reinosa
# Processing Record 17 of Set 12 | zhigansk
# Processing Record 18 of Set 12 | naze
# Processing Record 19 of Set 12 | quang ngai
# Processing Record 20 of Set 12 | dwarka
# Processing Record 21 of Set 12 | wilson
# Processing Record 22 of Set 12 | goulburn
# Processing Record 23 of Set 12 | port hedland
# Processing Record 24 of Set 12 | laje
# Processing Record 25 of Set 12 | adwa
# Processing Record 26 of Set 12 | portland
# Processing Record 27 of Set 12 | bubaque
# Processing Record 28 of Set 12 | karratha
# Processing Record 29 of Set 12 | mpika
# Processing Record 30 of Set 12 | parakai
# Processing Record 31 of Set 12 | aksarka
# Processing Record 32 of Set 12 | almaznyy
# Processing Record 33 of Set 12 | ati
# Processing Record 34 of Set 12 | cuiluan
# Processing Record 35 of Set 12 | toronto
# Processing Record 36 of Set 12 | labuan
# Processing Record 37 of Set 12 | belorechensk
# Processing Record 38 of Set 12 | zheleznodorozhnyy
# Processing Record 39 of Set 12 | landerneau
# Processing Record 40 of Set 12 | darhan
# Processing Record 41 of Set 12 | burica
# City not found. Skipping...
# Processing Record 42 of Set 12 | ghanzi
# Processing Record 43 of Set 12 | tieli
# Processing Record 44 of Set 12 | ensley
# Processing Record 45 of Set 12 | taybad
# Processing Record 46 of Set 12 | lancaster
# Processing Record 47 of Set 12 | siocon
# Processing Record 48 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 49 of Set 12 | pitimbu
# Processing Record 50 of Set 12 | wladyslawowo
# Processing Record 1 of Set 13 | nizwa
# Processing Record 2 of Set 13 | mvuma
# Processing Record 3 of Set 13 | ust-kuyga
# Processing Record 4 of Set 13 | puerto baquerizo moreno
# Processing Record 5 of Set 13 | giffoni valle piana
# Processing Record 6 of Set 13 | sihora
# Processing Record 7 of Set 13 | montrose
# Processing Record 8 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 9 of Set 13 | namibe
# Processing Record 10 of Set 13 | pacific grove
# Processing Record 11 of Set 13 | subate
# Processing Record 12 of Set 13 | matara
# Processing Record 13 of Set 13 | northam
# Processing Record 14 of Set 13 | alice springs
# Processing Record 15 of Set 13 | corinto
# Processing Record 16 of Set 13 | pangai
# Processing Record 17 of Set 13 | nanga eboko
# Processing Record 18 of Set 13 | xuddur
# Processing Record 19 of Set 13 | pedro juan caballero
# Processing Record 20 of Set 13 | skjervoy
# Processing Record 21 of Set 13 | tha bo
# Processing Record 22 of Set 13 | irtyshskiy
# Processing Record 23 of Set 13 | timbiqui
# Processing Record 24 of Set 13 | narsaq
# Processing Record 25 of Set 13 | kahului
# Processing Record 26 of Set 13 | luanda
# Processing Record 27 of Set 13 | lasa
# Processing Record 28 of Set 13 | half moon bay
# Processing Record 29 of Set 13 | mosna
# Processing Record 30 of Set 13 | gurupa
# Processing Record 31 of Set 13 | hue
# Processing Record 32 of Set 13 | mezhova
# Processing Record 33 of Set 13 | samsun
# Processing Record 34 of Set 13 | gamboma
# Processing Record 35 of Set 13 | grand-santi
# Processing Record 36 of Set 13 | ndende
# Processing Record 37 of Set 13 | moba
# Processing Record 38 of Set 13 | tete
# Processing Record 39 of Set 13 | espanola
# Processing Record 40 of Set 13 | kant
# Processing Record 41 of Set 13 | kavaratti
# Processing Record 42 of Set 13 | kedrovyy
# Processing Record 43 of Set 13 | dulce nombre de culmi
# Processing Record 44 of Set 13 | bima
# Processing Record 45 of Set 13 | ambovombe
# Processing Record 46 of Set 13 | canavieiras
# Processing Record 47 of Set 13 | cody
# Processing Record 48 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 49 of Set 13 | erdenet
# Processing Record 50 of Set 13 | horasan
# Processing Record 1 of Set 14 | dali
# Processing Record 2 of Set 14 | tezu
# Processing Record 3 of Set 14 | taltal
# Processing Record 4 of Set 14 | simbahan
# Processing Record 5 of Set 14 | gat
# Processing Record 6 of Set 14 | kissidougou
# Processing Record 7 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 8 of Set 14 | palmas
# Processing Record 9 of Set 14 | gbarnga
# Processing Record 10 of Set 14 | grindavik
# Processing Record 11 of Set 14 | troitsko-pechorsk
# Processing Record 12 of Set 14 | lagoa
# Processing Record 13 of Set 14 | eyl
# Processing Record 14 of Set 14 | ambon
# Processing Record 15 of Set 14 | macklin
# Processing Record 16 of Set 14 | yumen
# Processing Record 17 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 18 of Set 14 | afonso bezerra
# Processing Record 19 of Set 14 | hawalli
# Processing Record 20 of Set 14 | kutum
# Processing Record 21 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 22 of Set 14 | tadine
# Processing Record 23 of Set 14 | ambikapur
# Processing Record 24 of Set 14 | san policarpo
# Processing Record 25 of Set 14 | los algarrobos
# Processing Record 26 of Set 14 | broome
# Processing Record 27 of Set 14 | fairbanks
# Processing Record 28 of Set 14 | wasilla
# Processing Record 29 of Set 14 | chor
# Processing Record 30 of Set 14 | primore
# City not found. Skipping...
# Processing Record 31 of Set 14 | kozhva
# Processing Record 32 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 14 | moquegua
# Processing Record 34 of Set 14 | san andres
# Processing Record 35 of Set 14 | dicabisagan
# Processing Record 36 of Set 14 | solok
# Processing Record 37 of Set 14 | san jose
# Processing Record 38 of Set 14 | ulaangom
# Processing Record 39 of Set 14 | mangai
# Processing Record 40 of Set 14 | bouar
# Processing Record 41 of Set 14 | novyy urengoy
# Processing Record 42 of Set 14 | jieshi
# Processing Record 43 of Set 14 | waipawa
# Processing Record 44 of Set 14 | alekseyevka
# Processing Record 45 of Set 14 | ayia galini
# Processing Record 46 of Set 14 | zabol
# Processing Record 47 of Set 14 | sedhiou
# Processing Record 48 of Set 14 | oranjestad
# Processing Record 49 of Set 14 | balikpapan
# Processing Record 50 of Set 14 | campos novos
# Processing Record 1 of Set 15 | bell ville
# Processing Record 2 of Set 15 | roald
# Processing Record 3 of Set 15 | bambanglipuro
# Processing Record 4 of Set 15 | providencia
# Processing Record 5 of Set 15 | obo
# Processing Record 6 of Set 15 | saint-pierre
# Processing Record 7 of Set 15 | miraflores
# Processing Record 8 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 15 | dawlatabad
# Processing Record 10 of Set 15 | srednekolymsk
# Processing Record 11 of Set 15 | guarapari
# Processing Record 12 of Set 15 | venado tuerto
# Processing Record 13 of Set 15 | manta
# Processing Record 14 of Set 15 | zhaotong
# Processing Record 15 of Set 15 | hay river
# Processing Record 16 of Set 15 | athabasca
# Processing Record 17 of Set 15 | markova
# Processing Record 18 of Set 15 | chadiza
# Processing Record 19 of Set 15 | saint anthony
# Processing Record 20 of Set 15 | ulladulla
# Processing Record 21 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 22 of Set 15 | pattukkottai
# Processing Record 23 of Set 15 | kinkala
# Processing Record 24 of Set 15 | dharchula
# Processing Record 25 of Set 15 | horizontina
# Processing Record 26 of Set 15 | solnechnyy
# Processing Record 27 of Set 15 | tucurui
# Processing Record 28 of Set 15 | sokoto
# Processing Record 29 of Set 15 | coolum beach
# Processing Record 30 of Set 15 | kawalu
# Processing Record 31 of Set 15 | tateyama
# Processing Record 32 of Set 15 | bowen
# Processing Record 33 of Set 15 | suluova
# Processing Record 34 of Set 15 | cutro
# Processing Record 35 of Set 15 | teeli
# Processing Record 36 of Set 15 | emba
# Processing Record 37 of Set 15 | aripuana
# Processing Record 38 of Set 15 | teguldet
# Processing Record 39 of Set 15 | rudsar
# Processing Record 40 of Set 15 | khorixas
# Processing Record 41 of Set 15 | saldanha
# Processing Record 42 of Set 15 | banda aceh
# Processing Record 43 of Set 15 | chake chake
# Processing Record 44 of Set 15 | thai binh
# Processing Record 45 of Set 15 | saint quentin
# City not found. Skipping...
# Processing Record 46 of Set 15 | qiongshan
# Processing Record 47 of Set 15 | caravelas
# Processing Record 48 of Set 15 | vuktyl
# Processing Record 49 of Set 15 | petrivka
# Processing Record 50 of Set 15 | ahipara
# Processing Record 1 of Set 16 | legnica
# Processing Record 2 of Set 16 | chaykovskiy
# Processing Record 3 of Set 16 | olinda
# Processing Record 4 of Set 16 | mehamn
# Processing Record 5 of Set 16 | nuevitas
# Processing Record 6 of Set 16 | gornopravdinsk
# Processing Record 7 of Set 16 | olafsvik
# Processing Record 8 of Set 16 | buin
# Processing Record 9 of Set 16 | kyaikkami
# Processing Record 10 of Set 16 | ewa beach
# Processing Record 11 of Set 16 | nicolas bravo
# Processing Record 12 of Set 16 | camocim
# Processing Record 13 of Set 16 | wellington
# Processing Record 14 of Set 16 | south lake tahoe
# Processing Record 15 of Set 16 | pulandian
# Processing Record 16 of Set 16 | luceville
# City not found. Skipping...
# Processing Record 17 of Set 16 | valparaiso
# Processing Record 18 of Set 16 | killybegs
# Processing Record 19 of Set 16 | bekhtery
# Processing Record 20 of Set 16 | deep river
# Processing Record 21 of Set 16 | sorong
# Processing Record 22 of Set 16 | nayagarh
# Processing Record 23 of Set 16 | homer
# Processing Record 24 of Set 16 | erattupetta
# Processing Record 25 of Set 16 | tsienyane
# City not found. Skipping...
# Processing Record 26 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 16 | molteno
# Processing Record 28 of Set 16 | juegang
# Processing Record 29 of Set 16 | lorengau
# Processing Record 30 of Set 16 | sobolevo
# Processing Record 31 of Set 16 | dingle
# Processing Record 32 of Set 16 | tilichiki
# Processing Record 33 of Set 16 | zachagansk
# City not found. Skipping...
# Processing Record 34 of Set 16 | haines junction
# Processing Record 35 of Set 16 | kota belud
# Processing Record 36 of Set 16 | piacabucu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo      BR -22.9661  -42.0278     76.30        86          57
# 1  Charlottesville      US  38.0293  -78.4767     39.20        93          90
# 2     Port Lincoln      AU -34.7333  135.8667     70.38        57          64
# 3           Barrow      US  71.2906 -156.7887    -16.60        76          90
# 4             Kabo      CF   7.6994   18.6290     73.74        30          91
# 5       Georgetown      MY   5.4112  100.3354     89.01        66          20
# 6           Atuona      PF  -9.8000 -139.0333     79.02        75           3
# 7     Punta Arenas      CL -53.1500  -70.9167     41.00        75          75
# 8   Port Elizabeth      ZA -33.9180   25.5701     68.00        94          40
# 9          Iqaluit      CA  63.7506  -68.5145     -9.00        70           1
#
#    Wind Speed Current Description
# 0       26.84       broken clouds
# 1        2.04                 fog
# 2        9.78       broken clouds
# 3        6.91                haze
# 4        2.51     overcast clouds
# 5        8.05          few clouds
# 6       16.73           clear sky
# 7       11.50       broken clouds
# 8       13.80          light rain
# 9        5.75           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
